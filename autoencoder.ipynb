# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
from scipy import stats
import tensorflow as tf
import seaborn as sns
from pylab import rcParams
from sklearn.model_selection import train_test_split
from keras.models import Model, load_model
from keras.layers import Input, Dense
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras import regularizers

# %matplotlib inline

sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 14, 8

RANDOM_SEED = 42
LABELS = ["Normal", "Fraud"]

# %% [markdown]
# # Loading the data
#
# The dataset `creditcard.csv` is about credit card transactions that occurred during a period of two days, with 492 frauds out of 284,807 transactions.
#
# All variables in the dataset are numerical. The data has been transformed using PCA transformation(s) due to privacy reasons. The two features that haven't been changed are Time and Amount. Time contains the seconds elapsed between each transaction and the first transaction in the dataset.

# %%
import os

dataset_path = os.path.join('dataset', 'creditcard.csv')
df = pd.read_csv(dataset_path)

# %% [markdown]
# ## Exploration
#
# Since we directly use autoencoder to predict data, we need to remove some feautrue that have same desities both on normal data and fraud data.

# %%
print('origin shape:', df.shape)
df = df.drop(['V8', 'V13', 'V15', 'V20', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27'], axis=1)
print('now shape', df.shape)
# Out:
# origin shape: (284807, 31)
# now shape (284807, 21)

# %% [markdown]
# 31 columns, 2 of which are Time and Amount. The rest are output from the PCA transformation. Let's check for missing values:

# %%
df.isnull().values.any()
# Out:
# False

# %% [markdown]
# We have a highly imbalanced dataset on our hands. Normal transactions overwhelm the fraudulent ones by a large margin. Let's look at the two types of transactions:

# %%
frauds = df[df.Class == 1]
normal = df[df.Class == 0]

print('frauds shape:', frauds.shape)
print('normal shape:', normal.shape)
# Out:
# frauds shape: (492, 21)
# normal shape: (284315, 21)

# %% [markdown]
# How different are the amount of money used in different transaction classes?

# %%
frauds.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
normal.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %% [markdown]
# Do fraudulent transactions occur more often during certain time?

# %%
f, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
f.suptitle('Time of transaction vs Amount by class')

ax1.scatter(frauds.Time, frauds.Amount)
ax1.set_title('Fraud')

ax2.scatter(normal.Time, normal.Amount)
ax2.set_title('Normal')

plt.xlabel('Time (in Seconds)')
plt.ylabel('Amount')
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

data = df.drop(['Time'], axis=1)

data['Amount'] = StandardScaler().fit_transform(data['Amount'].values.reshape(-1, 1))

# %%
X_train, X_test = train_test_split(data, test_size=0.2, random_state=RANDOM_SEED)
X_train = X_train[X_train.Class == 0]
X_train = X_train.drop(['Class'], axis=1)

y_test = X_test['Class']
X_test = X_test.drop(['Class'], axis=1)

X_train = X_train.values
X_test = X_test.values

# %%
X_train.shape
# Out:
# (227451, 19)

# %% [markdown]
# # Building the model
#
# Our Autoencoder uses 4 fully connected layers with 30, 10, 10 and 19 neurons respectively.  The first two layers are used for our encoder, the last two go for the decoder. Additionally, L1 regularization will be used during training:

# %%
input_dim = X_train.shape[1]
encoding_dim = 30

input_layer = Input(shape=(input_dim, ))

encoder = Dense(encoding_dim, activation="tanh", 
                activity_regularizer=regularizers.l1(10e-5))(input_layer)
encoder = Dense(int(encoding_dim / 3), activation="relu")(encoder)

decoder = Dense(int(encoding_dim / 3), activation='tanh')(encoder)
decoder = Dense(input_dim, activation='relu')(decoder)
 
autoencoder = Model(inputs=input_layer, outputs=decoder)

# %% [markdown]
# Let's train our model for 100 epochs with a batch size of 32 samples and save the best performing model to a file. The ModelCheckpoint provided by Keras is really handy for such tasks. Additionally,  the training progress will be exported in a format that TensorBoard understands.

# %%
nb_epoch = 100
batch_size = 32

autoencoder.compile(optimizer='adam', 
                    loss='mean_squared_error', 
                    metrics=['accuracy'])

checkpointer = ModelCheckpoint(filepath="model.h5",
                               verbose=0,
                               save_best_only=True)
tensorboard = TensorBoard(log_dir='./logs',
                          histogram_freq=0,
                          write_graph=True,
                          write_images=True)

history = autoencoder.fit(X_train, X_train,
                    epochs=nb_epoch,
                    batch_size=batch_size,
                    shuffle=True,
                    validation_data=(X_test, X_test),
                    verbose=1,
                    callbacks=[checkpointer, tensorboard]).history
# Out:
# Epoch 1/100
#    1/7108 [..............................] - ETA: 2s - loss: 0.8991 - accuracy: 0.0312WARNING:tensorflow:From /usr/lib/python3.8/site-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0070s vs `on_train_batch_end` time: 0.0230s). Check your callbacks.
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.8734 - accuracy: 0.7120 - val_loss: 0.8464 - val_accuracy: 0.7810
# Epoch 2/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7872 - accuracy: 0.7939 - val_loss: 0.8114 - val_accuracy: 0.8078
# Epoch 3/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7644 - accuracy: 0.8190 - val_loss: 0.8032 - val_accuracy: 0.8308
# Epoch 4/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7572 - accuracy: 0.8304 - val_loss: 0.8051 - val_accuracy: 0.8289
# Epoch 5/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7527 - accuracy: 0.8378 - val_loss: 0.7975 - val_accuracy: 0.8371
# Epoch 6/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7487 - accuracy: 0.8403 - val_loss: 0.7919 - val_accuracy: 0.8486
# Epoch 7/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7447 - accuracy: 0.8410 - val_loss: 0.7876 - val_accuracy: 0.8393
# Epoch 8/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7404 - accuracy: 0.8471 - val_loss: 0.7858 - val_accuracy: 0.8484
# Epoch 9/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7383 - accuracy: 0.8489 - val_loss: 0.7837 - val_accuracy: 0.8553
# Epoch 10/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7370 - accuracy: 0.8521 - val_loss: 0.7852 - val_accuracy: 0.8499
# Epoch 11/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7348 - accuracy: 0.8578 - val_loss: 0.7834 - val_accuracy: 0.8640
# Epoch 12/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7324 - accuracy: 0.8645 - val_loss: 0.7887 - val_accuracy: 0.8301
# Epoch 13/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7315 - accuracy: 0.8650 - val_loss: 0.7791 - val_accuracy: 0.8733
# Epoch 14/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7311 - accuracy: 0.8666 - val_loss: 0.7783 - val_accuracy: 0.8750
# Epoch 15/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7304 - accuracy: 0.8669 - val_loss: 0.7814 - val_accuracy: 0.8588
# Epoch 16/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7293 - accuracy: 0.8677 - val_loss: 0.7772 - val_accuracy: 0.8685
# Epoch 17/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7295 - accuracy: 0.8684 - val_loss: 0.7776 - val_accuracy: 0.8735
# Epoch 18/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7292 - accuracy: 0.8680 - val_loss: 0.7770 - val_accuracy: 0.8780
# Epoch 19/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7285 - accuracy: 0.8705 - val_loss: 0.7790 - val_accuracy: 0.8574
# Epoch 20/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7282 - accuracy: 0.8704 - val_loss: 0.7786 - val_accuracy: 0.8735
# Epoch 21/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7275 - accuracy: 0.8714 - val_loss: 0.7778 - val_accuracy: 0.8740
# Epoch 22/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7273 - accuracy: 0.8718 - val_loss: 0.7769 - val_accuracy: 0.8700
# Epoch 23/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7278 - accuracy: 0.8722 - val_loss: 0.7839 - val_accuracy: 0.8575
# Epoch 24/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7270 - accuracy: 0.8716 - val_loss: 0.7754 - val_accuracy: 0.8817
# Epoch 25/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7265 - accuracy: 0.8728 - val_loss: 0.7763 - val_accuracy: 0.8756
# Epoch 26/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7263 - accuracy: 0.8724 - val_loss: 0.7766 - val_accuracy: 0.8679
# Epoch 27/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7261 - accuracy: 0.8723 - val_loss: 0.7756 - val_accuracy: 0.8711
# Epoch 28/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7262 - accuracy: 0.8723 - val_loss: 0.7772 - val_accuracy: 0.8663
# Epoch 29/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7257 - accuracy: 0.8730 - val_loss: 0.7784 - val_accuracy: 0.8735
# Epoch 30/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7260 - accuracy: 0.8722 - val_loss: 0.7771 - val_accuracy: 0.8769
# Epoch 31/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7262 - accuracy: 0.8725 - val_loss: 0.7777 - val_accuracy: 0.8618
# Epoch 32/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7258 - accuracy: 0.8704 - val_loss: 0.7759 - val_accuracy: 0.8732
# Epoch 33/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7259 - accuracy: 0.8722 - val_loss: 0.7762 - val_accuracy: 0.8728
# Epoch 34/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7259 - accuracy: 0.8710 - val_loss: 0.7744 - val_accuracy: 0.8764
# Epoch 35/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7261 - accuracy: 0.8716 - val_loss: 0.7785 - val_accuracy: 0.8646
# Epoch 36/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7256 - accuracy: 0.8724 - val_loss: 0.7745 - val_accuracy: 0.8777
# Epoch 37/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7260 - accuracy: 0.8714 - val_loss: 0.7747 - val_accuracy: 0.8773
# Epoch 38/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7254 - accuracy: 0.8724 - val_loss: 0.7746 - val_accuracy: 0.8788
# Epoch 39/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7262 - accuracy: 0.8721 - val_loss: 0.7761 - val_accuracy: 0.8780
# Epoch 40/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7251 - accuracy: 0.8724 - val_loss: 0.7759 - val_accuracy: 0.8705
# Epoch 41/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7254 - accuracy: 0.8730 - val_loss: 0.7752 - val_accuracy: 0.8760
# Epoch 42/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7255 - accuracy: 0.8707 - val_loss: 0.7773 - val_accuracy: 0.8567
# Epoch 43/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7248 - accuracy: 0.8719 - val_loss: 0.7750 - val_accuracy: 0.8683
# Epoch 44/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7253 - accuracy: 0.8718 - val_loss: 0.7751 - val_accuracy: 0.8694
# Epoch 45/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7250 - accuracy: 0.8719 - val_loss: 0.7738 - val_accuracy: 0.8762
# Epoch 46/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7250 - accuracy: 0.8724 - val_loss: 0.7763 - val_accuracy: 0.8694
# Epoch 47/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7248 - accuracy: 0.8724 - val_loss: 0.7756 - val_accuracy: 0.8696
# Epoch 48/100
# 7108/7108 [==============================] - 23s 3ms/step - loss: 0.7246 - accuracy: 0.8723 - val_loss: 0.7760 - val_accuracy: 0.8614
# Epoch 49/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7250 - accuracy: 0.8717 - val_loss: 0.7831 - val_accuracy: 0.8532
# Epoch 50/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7250 - accuracy: 0.8718 - val_loss: 0.7748 - val_accuracy: 0.8783
# Epoch 51/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7251 - accuracy: 0.8732 - val_loss: 0.7746 - val_accuracy: 0.8758
# Epoch 52/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7255 - accuracy: 0.8722 - val_loss: 0.7774 - val_accuracy: 0.8680
# Epoch 53/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7251 - accuracy: 0.8728 - val_loss: 0.7750 - val_accuracy: 0.8674
# Epoch 54/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7252 - accuracy: 0.8720 - val_loss: 0.7740 - val_accuracy: 0.8751
# Epoch 55/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7252 - accuracy: 0.8726 - val_loss: 0.7795 - val_accuracy: 0.8693
# Epoch 56/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7247 - accuracy: 0.8734 - val_loss: 0.7758 - val_accuracy: 0.8763
# Epoch 57/100
# 7108/7108 [==============================] - 22s 3ms/step - loss: 0.7252 - accuracy: 0.8729 - val_loss: 0.7731 - val_accuracy: 0.8799
# Epoch 58/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7252 - accuracy: 0.8733 - val_loss: 0.7766 - val_accuracy: 0.8643
# Epoch 59/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7251 - accuracy: 0.8723 - val_loss: 0.7739 - val_accuracy: 0.8744
# Epoch 60/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7245 - accuracy: 0.8747 - val_loss: 0.7756 - val_accuracy: 0.8647
# Epoch 61/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7247 - accuracy: 0.8737 - val_loss: 0.7735 - val_accuracy: 0.8689
# Epoch 62/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7247 - accuracy: 0.8746 - val_loss: 0.7736 - val_accuracy: 0.8741
# Epoch 63/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7247 - accuracy: 0.8741 - val_loss: 0.7726 - val_accuracy: 0.8794
# Epoch 64/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7247 - accuracy: 0.8738 - val_loss: 0.7730 - val_accuracy: 0.8805
# Epoch 65/100
# 7108/7108 [==============================] - 20s 3ms/step - loss: 0.7244 - accuracy: 0.8738 - val_loss: 0.7729 - val_accuracy: 0.8874
# Epoch 66/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7245 - accuracy: 0.8746 - val_loss: 0.7732 - val_accuracy: 0.8831
# Epoch 67/100
# 7108/7108 [==============================] - 21s 3ms/step - loss: 0.7243 - accuracy: 0.8743 - val_loss: 0.7732 - val_accuracy: 0.8765
# Epoch 68/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7240 - accuracy: 0.8750 - val_loss: 0.7727 - val_accuracy: 0.8762
# Epoch 69/100
# 7108/7108 [==============================] - 19s 3ms/step - loss: 0.7242 - accuracy: 0.8749 - val_loss: 0.7763 - val_accuracy: 0.8707
# Epoch 70/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7241 - accuracy: 0.8744 - val_loss: 0.7748 - val_accuracy: 0.8774
# Epoch 71/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7250 - accuracy: 0.8744 - val_loss: 0.7732 - val_accuracy: 0.8782
# Epoch 72/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7243 - accuracy: 0.8745 - val_loss: 0.7749 - val_accuracy: 0.8673
# Epoch 73/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7246 - accuracy: 0.8744 - val_loss: 0.7729 - val_accuracy: 0.8730
# Epoch 74/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7241 - accuracy: 0.8749 - val_loss: 0.7733 - val_accuracy: 0.8799
# Epoch 75/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7242 - accuracy: 0.8749 - val_loss: 0.7743 - val_accuracy: 0.8780
# Epoch 76/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7244 - accuracy: 0.8739 - val_loss: 0.7758 - val_accuracy: 0.8786
# Epoch 77/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7244 - accuracy: 0.8753 - val_loss: 0.7836 - val_accuracy: 0.8374
# Epoch 78/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7238 - accuracy: 0.8761 - val_loss: 0.7721 - val_accuracy: 0.8793
# Epoch 79/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7238 - accuracy: 0.8741 - val_loss: 0.7745 - val_accuracy: 0.8770
# Epoch 80/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7235 - accuracy: 0.8746 - val_loss: 0.7739 - val_accuracy: 0.8789
# Epoch 81/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7237 - accuracy: 0.8742 - val_loss: 0.7784 - val_accuracy: 0.8540
# Epoch 82/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7251 - accuracy: 0.8714 - val_loss: 0.7764 - val_accuracy: 0.8671
# Epoch 83/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7232 - accuracy: 0.8737 - val_loss: 0.7740 - val_accuracy: 0.8751
# Epoch 84/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7232 - accuracy: 0.8746 - val_loss: 0.7735 - val_accuracy: 0.8773
# Epoch 85/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7234 - accuracy: 0.8743 - val_loss: 0.7777 - val_accuracy: 0.8727
# Epoch 86/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7232 - accuracy: 0.8757 - val_loss: 0.7719 - val_accuracy: 0.8778
# Epoch 87/100
# 7108/7108 [==============================] - 18s 2ms/step - loss: 0.7235 - accuracy: 0.8744 - val_loss: 0.7729 - val_accuracy: 0.8737
# Epoch 88/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7235 - accuracy: 0.8743 - val_loss: 0.7734 - val_accuracy: 0.8716
# Epoch 89/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7238 - accuracy: 0.8746 - val_loss: 0.7743 - val_accuracy: 0.8733
# Epoch 90/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7233 - accuracy: 0.8738 - val_loss: 0.7717 - val_accuracy: 0.8833
# Epoch 91/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7233 - accuracy: 0.8739 - val_loss: 0.7725 - val_accuracy: 0.8739
# Epoch 92/100
# 7108/7108 [==============================] - 15s 2ms/step - loss: 0.7232 - accuracy: 0.8736 - val_loss: 0.7731 - val_accuracy: 0.8640
# Epoch 93/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7234 - accuracy: 0.8738 - val_loss: 0.7722 - val_accuracy: 0.8800
# Epoch 94/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7229 - accuracy: 0.8753 - val_loss: 0.7725 - val_accuracy: 0.8716
# Epoch 95/100
# 7108/7108 [==============================] - 18s 3ms/step - loss: 0.7231 - accuracy: 0.8731 - val_loss: 0.7713 - val_accuracy: 0.8760
# Epoch 96/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7230 - accuracy: 0.8737 - val_loss: 0.7746 - val_accuracy: 0.8702
# Epoch 97/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7224 - accuracy: 0.8738 - val_loss: 0.7720 - val_accuracy: 0.8752
# Epoch 98/100
# 7108/7108 [==============================] - 17s 2ms/step - loss: 0.7231 - accuracy: 0.8730 - val_loss: 0.7730 - val_accuracy: 0.8680
# Epoch 99/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7230 - accuracy: 0.8730 - val_loss: 0.7719 - val_accuracy: 0.8783
# Epoch 100/100
# 7108/7108 [==============================] - 16s 2ms/step - loss: 0.7224 - accuracy: 0.8747 - val_loss: 0.7723 - val_accuracy: 0.8685

# %% [markdown]
# # Evaluation

# %%
plt.plot(history['loss'])
plt.plot(history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right');

# %% [markdown]
# The reconstruction error on our training and test data seems to converge nicely. Is it low enough? Let's have a closer look at the error distribution:

# %%
predictions = autoencoder.predict(X_test)

mse = np.mean(np.power(X_test - predictions, 2), axis=1)
error_df = pd.DataFrame({'reconstruction_error': mse,
                        'true_class': y_test})

# %%
error_df.describe()
# Out:
#        reconstruction_error    true_class
# count          56962.000000  56962.000000
# mean               0.770213      0.001720
# std                4.158726      0.041443
# min                0.009805      0.000000
# 25%                0.198987      0.000000
# 50%                0.359737      0.000000
# 75%                0.641499      0.000000
# max              298.715441      1.000000

# %% [markdown]
# ## Reconstruction error without fraud

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
normal_error_df = error_df[(error_df['true_class']== 0) & (error_df['reconstruction_error'] < 10)]
_ = ax.hist(normal_error_df.reconstruction_error.values, bins=10)

# %% [markdown]
# ## Reconstruction error with fraud

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
fraud_error_df = error_df[error_df['true_class'] == 1]
_ = ax.hist(fraud_error_df.reconstruction_error.values, bins=10)

# %%
from sklearn.metrics import (confusion_matrix, precision_recall_curve, auc,
                             roc_curve, recall_score, classification_report, f1_score,
                             precision_recall_fscore_support)

# %% [markdown]
# ROC curves are very useful tool for understanding the performance of binary classifiers. However, our case is a bit out of the ordinary. We have a very imbalanced dataset. Nonetheless, let's have a look at our ROC curve:

# %%
fpr, tpr, thresholds = roc_curve(error_df.true_class, error_df.reconstruction_error)
roc_auc = auc(fpr, tpr)

plt.title('Receiver Operating Characteristic')
plt.plot(fpr, tpr, label='AUC = %0.4f'% roc_auc)
plt.legend(loc='lower right')
plt.plot([0,1],[0,1],'r--')
plt.xlim([-0.001, 1])
plt.ylim([0, 1.001])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show();

# %%
precision, recall, th = precision_recall_curve(error_df.true_class, error_df.reconstruction_error)
plt.plot(recall, precision, 'b', label='Precision-Recall curve')
plt.title('Recall vs Precision')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.show()

# %% [markdown]
# A high area under the curve represents both high recall and high precision, where high precision relates to a low false positive rate, and high recall relates to a low false negative rate. High scores for both show that the classifier is returning accurate results (high precision), as well as returning a majority of all positive results (high recall).

# %%
plt.plot(th, precision[1:], 'b', label='Threshold-Precision curve')
plt.title('Precision for different threshold values')
plt.xlabel('Threshold')
plt.ylabel('Precision')
plt.show()

# %% [markdown]
# You can see that as the reconstruction error increases our precision rises as well. Let's have a look at the recall:

# %%
plt.plot(th, recall[1:], 'b', label='Threshold-Recall curve')
plt.title('Recall for different threshold values')
plt.xlabel('Reconstruction error')
plt.ylabel('Recall')
plt.show()

# %% [markdown]
# Here, we have the exact opposite situation. As the reconstruction error increases the recall decreases.

# %% [markdown]
# # Prediction
#
# Our model is a bit different this time. It doesn't know how to predict new values. But we don't need that. In order to predict whether or not a new/unseen transaction is normal or fraudulent, we'll calculate the reconstruction error from the transaction data itself. If the error is larger than a predefined threshold, we'll mark it as a fraud (since our model should have a low error on normal transactions). Let's pick that value:

# %%
threshold = 85.0

# %% [markdown]
# And see how well we're dividing the two types of transactions:

# %%
groups = error_df.groupby('true_class')
fig, ax = plt.subplots()

for name, group in groups:
    ax.plot(group.index, group.reconstruction_error, marker='o', ms=3.5, linestyle='',
            label= "Fraud" if name == 1 else "Normal")
ax.hlines(threshold, ax.get_xlim()[0], ax.get_xlim()[1], colors="r", zorder=100, label='Threshold')
ax.legend()
plt.title("Reconstruction error for different classes")
plt.ylabel("Reconstruction error")
plt.xlabel("Data point index")
plt.show();

# %%
y_pred = [1 if e > threshold else 0 for e in error_df.reconstruction_error.values]

from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import average_precision_score
from sklearn.metrics import precision_recall_curve

confusion = confusion_matrix(y_test, y_pred)
print("Confusion matrix:\n%s" % confusion)
print('\n')
print(classification_report(y_test, y_pred))

precision, recall, _ = precision_recall_curve(y_test, y_pred)
plt.step(recall, precision, color='b', alpha=0.2, where='post')
plt.fill_between(recall, precision, step='post', alpha=0.2, color='b')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('2-class Precision-Recall curve: AUC={0:0.2f}'.format(average_precision_score(y_test, y_pred)))
# Out:
# Confusion matrix:
# [[56853    11]
#  [   75    23]]
#
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     56864
#            1       0.68      0.23      0.35        98
#
#     accuracy                           1.00     56962
#    macro avg       0.84      0.62      0.67     56962
# weighted avg       1.00      1.00      1.00     56962
# Text(0.5, 1.0, '2-class Precision-Recall curve: AUC=0.16')
